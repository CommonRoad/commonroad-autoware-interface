# %%
# import functions to read xml file and visualize commonroad objects
import matplotlib.pyplot as plt
from commonroad.common.file_reader import CommonRoadFileReader
from commonroad.visualization.mp_renderer import MPRenderer

# %%
# generate path of the file to be opened
file_path = "../data/sample-map-cr/sample-map-cr.xml"
# file_path = "/home/drivingsim/autoware/src/universe/autoware.universe/planning/tum_commonroad_planning/dfg-car/src/cr2autoware/data/ZAM_Over-1_1.xml"
# file_path = "sample-map-planning.xml"
# file_path = "/home/drivingsim/autoware/src/universe/autoware.universe/planning/tum_commonroad_planning/commonroad-scenario-designer/tests/map_conversion/test_maps/lanelet2/merging_lanelets_utm.xml"



# read in the scenario and planning problem set
scenario, planning_problem_set = CommonRoadFileReader(file_path).open()

# plot the planning problem and the scenario for the fifth time step
plt.figure(figsize=(20, 20))
rnd = MPRenderer()
scenario.draw(rnd, draw_params={'time_begin': 0})
planning_problem_set.draw(rnd)
rnd.render()
plt.show()

# %%
planning_problem = list(planning_problem_set.planning_problem_dict.values())[0]
planning_problem.goal.state_list[0].attributes
# Out:
# ['time_step']

# %%
file_path = "/home/drivingsim/autoware/src/universe/autoware.universe/planning/tum_commonroad_planning/dfg-car/src/cr2autoware/data/test_maps/lanelet2/sample-map-cr.xml"
scenario, planning_problem_set = CommonRoadFileReader(file_path).open()

# plot the planning problem and the scenario for the fifth time step
plt.figure(figsize=(20, 20))
rnd = MPRenderer()
scenario.draw(rnd, draw_params={'time_begin': 0})
planning_problem_set.draw(rnd)
rnd.render()
plt.show()

# %%
# file_path = "/home/drivingsim/autoware/src/universe/autoware.universe/planning/tum_commonroad_planning/dfg-car/src/cr2autoware/data/test_maps/lanelet2/sample-map-cr.xml"
file_path = "/home/drivingsim/autoware/src/universe/autoware.universe/planning/tum_commonroad_planning/dfg-car/src/cr2autoware/data/test_maps/lanelet2/merging_lanelets_utm/merging_lanelets_utm.xml"
file_path = "/home/drivingsim/autoware/src/universe/autoware.universe/planning/tum_commonroad_planning/dfg-car/src/cr2autoware/data/test_maps/lanelet2/urban-1_lanelets_utm/urban-1_lanelets_utm.xml"
# read in the scenario and planning problem set
scenario, planning_problem_set = CommonRoadFileReader(file_path).open()

# plot the planning problem and the scenario for the fifth time step
plt.figure(figsize=(10, 10))
rnd = MPRenderer()
scenario.draw(rnd, draw_params={'time_begin': 0})
planning_problem_set.draw(rnd)
rnd.render()
plt.show()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 33

# %%
file_path = "/home/drivingsim/autoware/src/universe/autoware.universe/planning/tum_commonroad_planning/dfg-car/src/cr2autoware/data/test_maps/lanelet2/merging_lanelets_utm_from_osm.xml"
scenario, planning_problem_set = CommonRoadFileReader(file_path).open()

plt.figure(figsize=(30, 30))
rnd = MPRenderer()
scenario.draw(rnd, draw_params={'time_begin': 0})
planning_problem_set.draw(rnd)
rnd.render()
plt.show()

# %%
file_path = "/home/drivingsim/autoware/src/universe/autoware.universe/planning/tum_commonroad_planning/dfg-car/src/cr2autoware/data/test_maps/lanelet2/sample-map-planning.xml"
scenario, planning_problem_set = CommonRoadFileReader(file_path).open()

plt.figure(figsize=(15, 15))
rnd = MPRenderer()
scenario.draw(rnd, draw_params={'time_begin': 0})
planning_problem_set.draw(rnd)
rnd.render()
plt.show()

file_path = "/home/drivingsim/autoware/src/universe/autoware.universe/planning/tum_commonroad_planning/dfg-car/src/cr2autoware/scripts/sample-map-planning-double-converted.xml"
scenario, planning_problem_set = CommonRoadFileReader(file_path).open()

plt.figure(figsize=(15, 15))
rnd = MPRenderer()
scenario.draw(rnd, draw_params={'time_begin': 0})
planning_problem_set.draw(rnd)
rnd.render()
plt.show()

# %%
file_path = "/home/drivingsim/autoware/src/universe/autoware.universe/planning/tum_commonroad_planning/dfg-car/src/cr2autoware/data/test_maps/lanelet2/sample-map-cr-small/sample-map-cr-small.xml"
scenario, planning_problem_set = CommonRoadFileReader(file_path).open()

plt.figure(figsize=(30, 30))
rnd = MPRenderer()
scenario.draw(rnd, draw_params={'time_begin': 0})
planning_problem_set.draw(rnd)
rnd.render()
plt.show()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 29
